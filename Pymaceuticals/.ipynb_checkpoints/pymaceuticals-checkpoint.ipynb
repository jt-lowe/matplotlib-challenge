# %% [markdown]
# # Observations and Insights
#
# ### Observation 1
#  - From our line plot, we can see that mouse s185's tumor decresed in volume over time when being treated with Capomulin
#
# ### Observation 2
#  - From our summary statistics table, it can be seen that Ramicane has the lowest values across all summarised values (mean,median,variance,standard deviation and SEM), this could indicate a high effectiveness for treating SCC tumor growth
#
# ### Observation 3
#  - Due to the positive correlation coefficient between Weight and Tumor Volume in Capomulin treated mice, we can say that heavier mice tend to have larger tumor volumes

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
merged_df = pd.merge(mouse_metadata,study_results,on="Mouse ID")

# Display the data table for preview
merged_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice.
total_mice= merged_df['Mouse ID'].unique()

print(f"There are {len(total_mice)} unique mice in the study")
# Out:
# There are 249 unique mice in the study

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
dupe_mice = merged_df[merged_df.duplicated(["Mouse ID","Timepoint"])]
    
dupe_mice
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 909     g989     Propriva  Female          21          26          0
# 911     g989     Propriva  Female          21          26          5
# 913     g989     Propriva  Female          21          26         10
# 915     g989     Propriva  Female          21          26         15
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 909           45.000000                 0
# 911           47.570392                 0
# 913           49.880528                 0
# 915           53.442020                 0
# 917           54.657650                 1

# %%
# Optional: Get all the data for the duplicate mouse ID. 
g989_df = merged_df.loc[merged_df['Mouse ID']=='g989',:]
g989_df
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
# 918     g989     Propriva  Female          21          26         25
# 919     g989     Propriva  Female          21          26         30
# 920     g989     Propriva  Female          21          26         35
#
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_df = merged_df.drop(g989_df.index)
clean_df.reset_index()
# Out:
#       index Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0         0     k403     Ramicane  Male          21          16          0
# 1         1     k403     Ramicane  Male          21          16          5
# 2         2     k403     Ramicane  Male          21          16         10
# 3         3     k403     Ramicane  Male          21          16         15
# 4         4     k403     Ramicane  Male          21          16         20
# ...     ...      ...          ...   ...         ...         ...        ...
# 1875   1888     z969     Naftisol  Male           9          30         25
# 1876   1889     z969     Naftisol  Male           9          30         30
# 1877   1890     z969     Naftisol  Male           9          30         35
# 1878   1891     z969     Naftisol  Male           9          30         40
# 1879   1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# ...

# %%
# Checking the number of mice in the clean DataFrame.
clean_total_mice= clean_df['Mouse ID'].unique()

print(f"There are now {len(clean_total_mice)} unique mice in the study")
# Out:
# There are now 248 unique mice in the study

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary dataframe.
drug_regi = clean_df.groupby(clean_df["Drug Regimen"])
drug_mean = drug_regi["Tumor Volume (mm3)"].mean().round(2)
drug_median = drug_regi["Tumor Volume (mm3)"].median().round(2)
drug_var = drug_regi["Tumor Volume (mm3)"].var().round(2)
drug_stddev = drug_regi["Tumor Volume (mm3)"].std().round(2)
drug_SEM = drug_regi["Tumor Volume (mm3)"].sem().round(2)

drug_df = pd.DataFrame({"Mean": drug_mean,
                       "Median":drug_median,
                       "Variance":drug_var,
                       "Std Dev":drug_stddev,
                       "SEM":drug_SEM})
drug_df
# Out:
#                Mean  Median  Variance  Std Dev   SEM
# Drug Regimen
# Capomulin     40.68   41.56     24.95     4.99  0.33
# Ceftamin      52.59   51.78     39.29     6.27  0.47
# Infubinol     52.88   51.82     43.13     6.57  0.49
# Ketapril      55.24   53.70     68.55     8.28  0.60
# Naftisol      54.33   52.51     66.17     8.13  0.60
# Placebo       54.03   52.29     61.17     7.82  0.58
# Propriva      52.32   50.45     43.85     6.62  0.54
# Ramicane      40.22   40.67     23.49     4.85  0.32
# Stelasyn      54.23   52.43     59.45     7.71  0.57
# Zoniferol     53.24   51.82     48.53     6.97  0.52

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Using the aggregation method, produce the same summary statistics in a single line
drug_agg_df = drug_regi["Tumor Volume (mm3)"].agg(['mean','median','var','std','sem']).round(2)
drug_agg_df
# Out:
#                mean  median    var   std   sem
# Drug Regimen
# Capomulin     40.68   41.56  24.95  4.99  0.33
# Ceftamin      52.59   51.78  39.29  6.27  0.47
# Infubinol     52.88   51.82  43.13  6.57  0.49
# Ketapril      55.24   53.70  68.55  8.28  0.60
# Naftisol      54.33   52.51  66.17  8.13  0.60
# Placebo       54.03   52.29  61.17  7.82  0.58
# Propriva      52.32   50.45  43.85  6.62  0.54
# Ramicane      40.22   40.67  23.49  4.85  0.32
# Stelasyn      54.23   52.43  59.45  7.71  0.57
# Zoniferol     53.24   51.82  48.53  6.97  0.52

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using Pandas.

tp_count = drug_regi["Timepoint"].count()

tp_bar_panda = tp_count.plot(kind="bar")

tp_bar_panda.set_ylabel("Total Number of Timepoints")
tp_bar_panda.set_title("Total Timepoints per Drug")
# Out:
# Text(0.5, 1.0, 'Total Timepoints per Drug')

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using pyplot.
x_axis=tp_count.index

plt.bar(x_axis,tp_count)
plt.xticks(rotation="90")
plt.xlabel("Drug Regimen")
plt.ylabel("Total Number of Timepoints")
plt.title("Total Timepoints per Drug")
# Out:
# Text(0.5, 1.0, 'Total Timepoints per Drug')

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
labels = ["Male", "Female"]
sex = clean_df['Sex'].value_counts()
colors = ['blue','pink']

mf_pie = clean_df['Sex'].value_counts().plot(kind="pie",colors=colors,autopct='%1.1f%%',startangle=90)
mf_pie.set_ylabel('')
mf_pie.set_xlabel('Distribution of Sex')
# Out:
# Text(0.5, 0, 'Distribution of Sex')

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

plt.pie(sex, labels=labels, colors=colors, autopct="%1.1f%%", startangle = 90)
plt.xlabel("Distribtion of Sex")
# Out:
# Text(0.5, 0, 'Distribtion of Sex')

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse
mouse_df = clean_df.groupby("Mouse ID")

max_tp_mouse = mouse_df["Timepoint"].max()
max_tp_mouse
#Merge this group df with the original dataframe to get the tumor volume at the last timepoint
clean_max = pd.merge(clean_df,max_tp_mouse, on="Mouse ID")

clean_max = clean_max.rename(columns={"Timepoint_x":"Timepoint",
                                               "Timepoint_y":"Max Timepoint"})
clean_max
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1875     z969     Naftisol  Male           9          30         25
# 1876     z969     Naftisol  Male           9          30         30
# 1877     z969     Naftisol  Male           9          30         35
# 1878     z969     Naftisol  Male           9          30         40
# 1879     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites  Max Timepoint
# 0              45.000000                 0             45
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatments = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']

# Create empty list to fill with tumor vol data (for plotting)
tumor_vol = []

# Calculate the IQR and quantitatively determine if there are any potential outliers. 
for drug in treatments:

    # Locate the rows which contain mice on each drug and get the tumor volumes
    treat = clean_max.loc[clean_max["Drug Regimen"]==drug,:]
    
    # add subset 
    max_treat=treat.loc[treat["Timepoint"]==treat["Max Timepoint"]]
    
    tumor_vol.append(max_treat["Tumor Volume (mm3)"]) 
    
    # Determine outliers using upper and lower bounds
    quartiles = max_treat["Tumor Volume (mm3)"].quantile([.25,.5,.75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = upperq-lowerq

    print(f"For {drug}")
    print("\n")    
    
    print(f"The lower quartile value is: {lowerq:.2f}")
    print(f"The upper quartile value is: {upperq:.2f}")
    print(f"The median is: {quartiles[0.5]:.2f} ")
    print(f"The interquartile range is: {iqr:.2f}")

    print("\n")

    lower_bound = lowerq - (1.5*iqr)
    upper_bound = upperq + (1.5*iqr)
    
    print(f"Tumors with a volume less than {lower_bound:.2f}(mm3) and greater than {upper_bound:.2f}(mm3) could be considered outliers")

    print("\n")
# Out:
# For Capomulin
#
#
# The lower quartile value is: 32.38
# The upper quartile value is: 40.16
# The median is: 38.13
# The interquartile range is: 7.78
#
#
# Tumors with a volume less than 20.70(mm3) and greater than 51.83(mm3) could be considered outliers
#
#
# For Ramicane
#
#
# The lower quartile value is: 31.56
# The upper quartile value is: 40.66
# The median is: 36.56
# The interquartile range is: 9.10
#
#
# Tumors with a volume less than 17.91(mm3) and greater than 54.31(mm3) could be considered outliers
#
#
# For Infubinol
#
#
# The lower quartile value is: 54.05
# The upper quartile value is: 65.53
# The median is: 60.17
# The interquartile range is: 11.48
#
#
# Tumors with a volume less than 36.83(mm3) and greater than 82.74(mm3) could be considered outliers
#
#
# For Ceftamin
#
#
# The lower quartile value is: 48.72
# The upper quartile value is: 64.30
# The median is: 59.85
# The interquartile range is: 15.58
#
#
# ...

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
flierprops = dict(marker='o', markerfacecolor='red', markersize=8)

tum_boxplot = plt.boxplot(tumor_vol,labels=treatments,flierprops=flierprops)



plt.title("Summary of Tumor Volume")
plt.ylabel("Tumor Volume (mm3)")
plt.xlabel("Drug Regimen")
# Out:
# Text(0.5, 0, 'Drug Regimen')

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin

#find all mice that were treated with Capomulin
cap_mice = clean_df[clean_df['Drug Regimen']=='Capomulin']

cap_mice
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 10       s185    Capomulin  Female           3          17          0
# 11       s185    Capomulin  Female           3          17          5
# 12       s185    Capomulin  Female           3          17         10
# 13       s185    Capomulin  Female           3          17         15
# 14       s185    Capomulin  Female           3          17         20
# ...       ...          ...     ...         ...         ...        ...
# 440      i557    Capomulin  Female           1          24         45
# 1452     r157    Capomulin    Male          22          25          0
# 1453     r157    Capomulin    Male          22          25          5
# 1454     r157    Capomulin    Male          22          25         10
# 1455     r157    Capomulin    Male          22          25         15
#
#       Tumor Volume (mm3)  Metastatic Sites
# 10             45.000000                 0
# ...

# %%
#select mouse from cap_mice set, first mouse is s185
cap_mouse = clean_df.loc[clean_df['Mouse ID']=='s185',:]
cap_mouse

plt.plot(cap_mouse["Timepoint"],cap_mouse["Tumor Volume (mm3)"])
plt.xlabel("Time")
plt.ylabel("Tumor Volume (mm3)")
plt.title("Mouse s185's Tumor Volume over Time")
# Out:
# Text(0.5, 1.0, "Mouse s185's Tumor Volume over Time")

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
avg_tum_vol=cap_mice.groupby('Mouse ID').mean()


plt.scatter(avg_tum_vol['Weight (g)'],avg_tum_vol['Tumor Volume (mm3)'])
plt.xlabel("Mouse Weight (g)")
plt.ylabel("Tumor Volume (mm3)")
plt.title("Capomulin Treated Mouse Weight vs Average Tumor Volume")
# Out:
# Text(0.5, 1.0, 'Capomulin Treated Mouse Weight vs Average Tumor Volume')

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
(slope,intercept,rvalue,pvalue,stderr)=st.linregress(avg_tum_vol['Weight (g)'], avg_tum_vol["Tumor Volume (mm3)"])

print(f"The correlation coefficient between the weight (g) and tumor volume (mm3) of Capomulin treated mice is: {rvalue:.2f}")

line = slope*avg_tum_vol['Weight (g)']+intercept

plt.plot(avg_tum_vol['Weight (g)'],line,color='red')
plt.scatter(avg_tum_vol['Weight (g)'],avg_tum_vol["Tumor Volume (mm3)"])
plt.xlabel("Mouse Weight (g)")
plt.ylabel("Tumor Volume (mm3)")
plt.title("Capomulin Treated Mouse Weight vs Average Tumor Volume")
# Out:
# The correlation coefficient between the weight (g) and tumor volume (mm3) of Capomulin treated mice is: 0.84
# Text(0.5, 1.0, 'Capomulin Treated Mouse Weight vs Average Tumor Volume')
